# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import googlemaps

# %%
gmaps = googlemaps.Client(key='AIzaSyCJ5CbvD-Xy5DIfAA9hTRUISVPVe-3qQf8')

reverse_geocode_result = gmaps.reverse_geocode((33.3024873661656, 126.39331824294100), language='ko')
print(reverse_geocode_result)
# Out:
# [{'address_components': [{'long_name': '379', 'short_name': '379', 'types': ['premise']}, {'long_name': '상천리', 'short_name': '상천리', 'types': ['political', 'sublocality', 'sublocality_level_3']}, {'long_name': '안덕면', 'short_name': '안덕면', 'types': ['political', 'sublocality', 'sublocality_level_2']}, {'long_name': '서귀포시', 'short_name': '서귀포시', 'types': ['locality', 'political']}, {'long_name': '제주특별자치도', 'short_name': '제주특별자치도', 'types': ['administrative_area_level_1', 'political']}, {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']}], 'formatted_address': '대한민국 제주특별자치도 서귀포시 안덕면 상천리 379', 'geometry': {'location': {'lat': 33.3026006, 'lng': 126.3933167}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 33.30394958029149, 'lng': 126.3946656802915}, 'southwest': {'lat': 33.30125161970849, 'lng': 126.3919677197085}}}, 'place_id': 'ChIJncx3NDVaDDUR994xnZOhb3k', 'plus_code': {'global_code': '8Q58893V+28'}, 'types': ['street_address']}, {'address_compone
# ...

# %%
#전체 제주 노드 위도, 경도를 google api reverse geocoding 해서 주소로 바꿈
df = pd.read_csv('data/Jeju_nodes.csv')

def get_address(row):
    try:
        reverse_geocode_result = gmaps.reverse_geocode((row['latitude'], row['longitude']), language='ko')
        

        if reverse_geocode_result:
        
            print(reverse_geocode_result[0]['formatted_address'])
            return reverse_geocode_result[0]['formatted_address']
        else:
            return None
    except Exception as e:
        print(e)
        return None
    

df['address'] = df.apply(get_address, axis=1)
# Out:
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# name 'gmaps' is not defined
# ...

# %%
address = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8', sep=';')
address.head()
# Out:
#            Id  NODE_TYPE  NODE_NAME  TURN_P  UPDATEDATE  REMARK  HIST_TYPE  \
# 0  4060029000        101  서홍동1481-1       0    20230519     NaN        NaN
# 1  4060187801        101       디아넥스       1    20230519     NaN        NaN
# 2  4060014200        101        대기정       1    20230519     NaN        NaN
# 3  4050113000        102   함덕리828-3       0    20230519     NaN        NaN
# 4  4050113700        102   북촌리187-2       0    20230519     NaN        NaN
#
#    HISTREMARK   latitude   longitude                         address
# 0         NaN  33.254678  126.512735      대한민국 제주특별자치도 서귀포시 서홍동 1462
# 1         NaN  33.302487  126.393318   대한민국 제주특별자치도 서귀포시 안덕면 상천리 379
# 2         NaN  33.240456  126.427825    대한민국 제주특별자치도 서귀포시 중문동 2753-1
# 3         NaN  33.529426  126.667921  대한민국 제주특별자치도 제주시 조천읍 함덕리 828-1
# 4         NaN  33.543350  126.702718  대한민국 제주특별자치도 제주시 조천읍 북촌리 199-1

# %%
population = pd.read_csv('data/제주시_주민등록인구및세대현황 final.csv', encoding='utf-8', sep=';')
population
# Out:
#                                 행정구역  2023년10월_총인구수  2023년10월_세대수  \
# 0   제주특별자치도 제주특별자치도 제주시 (5011000000)        492.233       224.482
# 1        제주특별자치도 제주시 한림읍(5011025000)         20.980        10.768
# 2        제주특별자치도 제주시 애월읍(5011025300)         37.826        17.698
# 3        제주특별자치도 제주시 구좌읍(5011025600)         15.358         8.055
# 4        제주특별자치도 제주시 조천읍(5011025900)         25.785        11.971
# 5        제주특별자치도 제주시 한경면(5011031000)          9.597         5.154
# 6        제주특별자치도 제주시 추자면(5011032000)          1.577       952.000
# 7        제주특별자치도 제주시 우도면(5011033000)          1.612       860.000
# 8       제주특별자치도 제주시 일도일동(5011051000)          2.200         1.335
# 9       제주특별자치도 제주시 일도이동(5011052000)         31.642        13.455
# 10      제주특별자치도 제주시 이도일동(5011053000)          7.652         3.954
# 11      제주특별자치도 제주시 이도이동(5011054000)         48.777        21.454
# 12      제주특별자치도 제주시 삼도일동(5011055000)         12.982         6.048
# ...

# %%
#adrees column에서 읍 면 동 셋 중 하나로 끝나는 단어만 출력
def filter_address_parts(address):
    parts = address.split()
    filtered_parts = [part for part in parts if part.endswith(('읍', '면', '동'))]
    return ' '.join(filtered_parts)

address['filtered_address'] = address['address'].apply(filter_address_parts)
address.head()
# Out:
#            Id  NODE_TYPE  NODE_NAME  TURN_P  UPDATEDATE  REMARK  HIST_TYPE  \
# 0  4060029000        101  서홍동1481-1       0    20230519     NaN        NaN
# 1  4060187801        101       디아넥스       1    20230519     NaN        NaN
# 2  4060014200        101        대기정       1    20230519     NaN        NaN
# 3  4050113000        102   함덕리828-3       0    20230519     NaN        NaN
# 4  4050113700        102   북촌리187-2       0    20230519     NaN        NaN
#
#    HISTREMARK   latitude   longitude                         address  \
# 0         NaN  33.254678  126.512735      대한민국 제주특별자치도 서귀포시 서홍동 1462
# 1         NaN  33.302487  126.393318   대한민국 제주특별자치도 서귀포시 안덕면 상천리 379
# 2         NaN  33.240456  126.427825    대한민국 제주특별자치도 서귀포시 중문동 2753-1
# 3         NaN  33.529426  126.667921  대한민국 제주특별자치도 제주시 조천읍 함덕리 828-1
# 4         NaN  33.543350  126.702718  대한민국 제주특별자치도 제주시 조천읍 북촌리 199-1
#
#   filtered_address
# 0              서홍동
# 1              안덕면
# 2              중문동
# ...

# %%
address.to_csv('data/Jeju_nodes.csv', index=False, encoding='utf-8', sep=';')

# %%
address.head(10)
# Out:
#            Id  NODE_TYPE  NODE_NAME  TURN_P  UPDATEDATE  REMARK  HIST_TYPE  \
# 0  4060029000        101  서홍동1481-1       0    20230519     NaN        NaN
# 1  4060187801        101       디아넥스       1    20230519     NaN        NaN
# 2  4060014200        101        대기정       1    20230519     NaN        NaN
# 3  4050113000        102   함덕리828-3       0    20230519     NaN        NaN
# 4  4050113700        102   북촌리187-2       0    20230519     NaN        NaN
# 5  4050113900        102    북촌리2688       0    20230519     NaN        NaN
# 6  4060000800        101     대천동사무소       1    20230519     NaN        NaN
# 7  4060003403        101      나나다육이       1    20230519     NaN        NaN
# 8  4060004001        101   신효동893-1       0    20230519     NaN        NaN
# 9  4060004201        101      세훈빌리지       0    20230519     NaN        NaN
#
#    HISTREMARK   latitude   longitude                          address  \
# 0         NaN  33.254678  126.512735       대한민국 제주특별자치도 서귀포시 서홍동 1462
# ...

# %%
address = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8', sep=';')

# fltered_address 각 읍 면 동 별로 노드 개수 저장
counts = address['filtered_address'].value_counts()
output_csv_path = 'data/filtered_address_counts.csv'
counts.to_csv(output_csv_path, encoding='utf-8', index=True)

# %%
#행정구역 column에서 읍 면 동 셋 중 하나로 끝나는 단어만 출력
import re
import numpy as np
population = pd.read_csv('data/제주시_주민등록인구및세대현황 final.csv', encoding='utf-8', sep=';')
def add_space_to_address_parts(행정구역):
    return re.sub(r'(읍|면|동)\(', r'\1 (', 행정구역)

population['행정구역'] = population['행정구역'].apply(add_space_to_address_parts)

def filter_address_parts(population):
    parts = population.split()
    filtered_parts = [part for part in parts if part.endswith(('읍', '면', '동'))]
    return ' '.join(filtered_parts)

population['filtered_address'] = population['행정구역'].apply(filter_address_parts)


#nodes count column 만들어서 추가 행정동 기준으로 분류되어 있으므로 각 다음과 같은 법정동을 포함한다. 제주시 봉개동: 봉개동, 용강동, 회천동/ 노형동: 노형동, 해안/ 외도동: 내도동, 도평동
node_counts = [0, 194, 304, 178, 207, 105, 0, 0, 18, 19, 19, 98, 11, 25, 29, 35, 40, 94, 37, 58, 87, 60, 106, 225, 55, 23, 37]
population['nodes count'] = node_counts


#node 당 averge population을 구한다
population['2023년10월_총인구수'] = population['2023년10월_총인구수'].astype(str)
population['2023년10월_총인구수'] = population['2023년10월_총인구수'].str.replace('.', '').astype(int)
population['average population'] = population['2023년10월_총인구수'] / population['nodes count']
population['average population'] = population['average population'].replace([np.inf, -np.inf], np.nan)

population.to_csv('data/제주시_주민등록인구및세대현황 final.csv', encoding='utf-8', sep=';')
# Out:
# /var/folders/w5/y3945d710kx89qc8855pnv600000gn/T/ipykernel_18788/2819103965.py:25: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   population['2023년10월_총인구수'] = population['2023년10월_총인구수'].str.replace('.', '').astype(int)

# %%
#행정구역 column에서 읍 면 동 셋 중 하나로 끝나는 단어만 출력
population2 = pd.read_csv('data/서귀포시_주민등록인구및세대현황.csv', encoding='cp949', sep=',')
population2
def add_space_to_address_parts(행정구역):
    return re.sub(r'(읍|면|동)\(', r'\1 (', 행정구역)

population2['행정구역'] = population2['행정구역'].apply(add_space_to_address_parts)
def filter_address_parts(population2):
    parts = population2.split()
    filtered_parts = [part for part in parts if part.endswith(('읍', '면', '동'))]
    return ' '.join(filtered_parts)

population2['filtered_address'] = population2['행정구역'].apply(filter_address_parts)
population2
#nodes count column 만들어서 추가 행정동 기준으로 분류되어 있으므로 각 다음과 같은 법정동을 포함한다. 서귀포시 송산동:동홍동, 보목동, 0.5토평동, 0.25서귀동/ 정방동: 0.25서귀동
#중앙동: 0.25서귀동/ 천지동: 0.25서귀동/ 효돈동: 신효동, 하효동/ 영천동:상효동, 0.5토평동 / 대륜동: 법환동,호근/ 대천동:강정동, 도순동,영남동, 월평동/ 중문동: 대포동 하원동 회수동/ 예래동: 색달동, 상예동, 하예동
node_counts = [0, 224, 332, 192, 189, 175, 198, 13, 14, 14, 46, 69, 148, 125, 45, 129, 95, 98]
population2['nodes count'] = node_counts


#node 당 averge population을 구한다
population2['2023년10월_총인구수'] = population2['2023년10월_총인구수'].astype(str)
population2['2023년10월_총인구수'] = population2['2023년10월_총인구수'].str.replace(',', '').astype(int)
population2['average population'] = population2['2023년10월_총인구수'] / population2['nodes count']
population2['average population'] = population2['average population'].replace([np.inf, -np.inf], np.nan)

population2.to_csv('data/서귀포시_주민등록인구및세대현황.csv', encoding='utf-8', sep=';')

# %%
import pandas as pd
import numpy as np
import networkx as nx

import matplotlib.pyplot as plt
# 읍 면 동이 행정동으로 구별된 것을 지도에 그리기

# %%
nodes = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8',sep=',')
links = pd.read_csv('data/Jeju_links.csv', encoding='cp949')
links
nodes = nodes[['Id','NODE_NAME','latitude','longitude','filtered_address','average population']]
links = links[['Source','Target']]

# %%
source_in = links['Source'].apply(lambda x : x in list(nodes['Id'])) # check Sources are in jeju_id
target_in = links['Target'].apply(lambda x : x in list(nodes['Id'])) # check Targets are in jeju_id
# source_in and target_in are boolean type pandas.Series which contains True or False
Jeju_links = links[source_in & target_in] # contain if both target and source are contained in jeju_id

# %%
G = nx.Graph()
# R is the Earth's radius
R = 6371e3

for idx,row in nodes.iterrows():
    # add node to Graph G
    G.add_node(row['Id'],Label=row['NODE_NAME'],latitude=row['latitude'], longitude=row['longitude'])

for idx,row in Jeju_links.iterrows():
    ## Calculate the distance between Source and Target Nodes
    lon1 = float(nodes[nodes['Id'] == row['Source']]['longitude'] * np.pi/180)
    lat1 = float(nodes[nodes['Id'] == row['Source']]['latitude'] * np.pi/180)
    lon2 = float(nodes[nodes['Id'] == row['Target']]['longitude'] * np.pi/180)
    lat2 = float(nodes[nodes['Id'] == row['Target']]['latitude'] * np.pi/180)
    d_lat = lat2 - lat1
    d_lon = lon2 - lon1
    a = np.sin(d_lat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(d_lon/2) ** 2
    c = 2 * np.arctan2(a**0.5, (1-a) ** 0.5)
    d = R * c
    
    # Link attribute : 'Source', 'Target' and weight = 'Length between them'
    G.add_edge(row['Source'],row['Target'],weight = d)
    
# make a dictionary for node position
pos = {}
for node in G.nodes(data=True):
    pos[node[0]] = [node[1]['longitude'], node[1]['latitude']]
print(pos)
# Out:
# {4060029000: [126.512734734648, 33.2546781470705], 4060187801: [126.393318242941, 33.3024873661656], 4060014200: [126.427824763833, 33.2404562739723], 4050113000: [126.667921008318, 33.5294259271958], 4050113700: [126.702717929053, 33.5433495414616], 4050113900: [126.693206207319, 33.5500237666183], 4060000800: [126.478039080718, 33.2511516704185], 4060003403: [126.595401810657, 33.259624267661], 4060004001: [126.612293095372, 33.2611697419915], 4060004201: [126.428245623643, 33.258049186505], 4060073300: [126.467102315343, 33.263421015703], 4060073400: [126.474326735403, 33.2561718396282], 4060073900: [126.514023434851, 33.2366074758841], 4060074300: [126.475651731667, 33.2362573635155], 4060076200: [126.561106833762, 33.2468565391276], 4050000503: [126.489959245415, 33.41828117736], 4050000600: [126.616698292577, 33.4191031477377], 4050129700: [126.258499828867, 33.3048245714679], 4050130300: [126.259139099184, 33.4094155336075], 4050164300: [126.405096018178, 33.4836605799511], 40
# ...

# %%
from matplotlib.colors import ListedColormap

unique_addresses = nodes['filtered_address'].unique()
color_map = plt.cm.get_cmap('hsv', len(unique_addresses))
address_color = {address: color_map(i) for i, address in enumerate(unique_addresses)}

# %%
# 노드별 색상 리스트 
node_colors = [address_color[nodes[nodes['Id'] == node]['filtered_address'].values[0]] for node in G.nodes()]
# "G" is a network, "nodelist" is a list of node to select
def draw(G, pos, node_colors):
    plt.figure(figsize=(12, 7))
    plt.axis('off')

    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=3)
    nx.draw_networkx_edges(G, pos, edge_color='grey')
    plt.show()
draw(G, pos, node_colors)

# %%
#인구수 별로 그림, 인구수 0은 검정색
unique_addresses = nodes['average population'].unique()
color_map = plt.cm.get_cmap('hsv', len(unique_addresses))
address_color = {address: color_map(i) for i, address in enumerate(unique_addresses)}

def get_node_attributes(node):
    avg_population = nodes[nodes['Id'] == node]['average population'].values[0]
    color = address_color[avg_population]
    size = 3
    if avg_population <100 :
        color = 'black'
        size = 0
    return color, size

node_colors = []
node_sizes = []
for node in G.nodes():
    color, size = get_node_attributes(node)
    node_colors.append(color)
    node_sizes.append(size)


def draw(G, pos, node_colors, node_sizes):
    plt.figure(figsize=(12, 7))
    plt.axis('off')

    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=node_sizes)
    nx.draw_networkx_edges(G, pos, edge_color='grey')
    plt.show()

draw(G, pos, node_colors, node_sizes)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1026: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.asanyarray(x)

# %%
print(nodes.columns)
# Out:
# Index(['Id', 'NODE_NAME', 'latitude', 'longitude', 'filtered_address'], dtype='object')

# %%
population2 = pd.read_csv('data/서귀포시_주민등록인구및세대현황.csv', encoding='utf-8', sep=';')
population2
# Out:
#     Unnamed: 0                               행정구역  2023년10월_총인구수 2023년10월_세대수  \
# 0            0  제주특별자치도 제주특별자치도 서귀포시 (5013000000)         183886       88,809
# 1            1      제주특별자치도 서귀포시 대정읍 (5013025000)          22102       10,810
# 2            2      제주특별자치도 서귀포시 남원읍 (5013025300)          18381        8,851
# 3            3      제주특별자치도 서귀포시 성산읍 (5013025900)          15210        8,158
# 4            4      제주특별자치도 서귀포시 안덕면 (5013031000)          12520        6,472
# 5            5      제주특별자치도 서귀포시 표선면 (5013032000)          12594        6,322
# 6            6      제주특별자치도 서귀포시 송산동 (5013051000)           3855        1,884
# 7            7      제주특별자치도 서귀포시 정방동 (5013052000)           2144        1,334
# 8            8      제주특별자치도 서귀포시 중앙동 (5013053000)           3174        1,836
# 9            9      제주특별자치도 서귀포시 천지동 (5013054000)           3474        2,023
# 10          10      제주특별자치도 서귀포시 효돈동 (5013055000)           5280        2,391
# ...

# %%
nodes = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8')
population_mapping = {
    '한림읍': 10.814433, '애월읍': 124.427632, '구좌읍': 86.280899, '조천읍': 124.565217, '한경면': 91.400000, '추자면': 0, '우도면': 0,
    '일도일동': 1.222222, '일도이동': 1665.368421, '이도일동': 402.736842, '이도이동': 497.724490, '삼도일동': 1180.181818, '삼도이동': 307.880000,
    '용담일동': 229.379310, '용담이동': 396.514286, '건입동': 220.125000, '화북동': 248.882979, '삼양동': 712.405405, '봉개동': 91, '용강동': 91,
    '회천동': 91, '아라동': 459.045977, '오라동': 266.083333, '연동': 402.150943, '노형동': 246.235556, '해안동': 246.235556, '외도동': 410.290909,
    '내도동': 410.290909, '도평동': 410.290909, '이호동': 192.565217, '도두동': 87.918919, '대정읍': 98.669643, '남원읍': 55.364458, '성산읍': 79.218750,
    '안덕면': 66.243386, '표선면': 71.965714, '송산동': 19.469697, '동홍동': 19.469697, '보목동': 19.469697, '토평동': 48.010211, '정방동': 164.923077,
    '중앙동': 226.714286, '천지동': 248.142857, '서귀동': 164.81247925, '신효동': 114.782609, '하효동': 114.782609, '효돈동': 114.782609, '영천동': 76.550725,
    '서홍동': 76.550725, '대륜동': 342.466667, '법환동': 342.466667, '호근동': 342.466667, '대천동': 106.023256, '강정동': 106.023256, '도순동': 106.023256,
    '영남동': 106.023256, '월평동': 106.023256, '중문동': 130.484211, '대포동': 130.484211, '하원동': 130.484211, '회수동': 130.484211, '예래동': 39.122449,
    '색달동': 39.122449, '상예동': 39.122449, '하예동': 39.122449
}


nodes['average population'] = nodes['filtered_address'].map(population_mapping).fillna(0)

nodes.to_csv('data/Jeju_nodes.csv', index=False)

# %%
# serviCe Area에 포함되는 노드들의 average_poplaton을 합쳐서 색의 투명도를 디르게 칠하기

# %%
import pandas as pd
import networkx as nx
from haversine import haversine
import matplotlib.pyplot as plt


nodes = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8')
links = pd.read_csv('data/Jeju_links.csv', encoding='cp949')
car = pd.read_csv('data/Jeju_car.csv', encoding='cp949')


nodes = nodes[['Id', 'NODE_NAME', 'latitude', 'longitude', 'average population']]
links = links[['Source', 'Target', '시간']]
source_in = links['Source'].apply(lambda x: x in list(nodes['Id']))
target_in = links['Target'].apply(lambda x: x in list(nodes['Id']))
jeju_links = links[source_in & target_in]

# %%
G = nx.Graph()

for idx, row in nodes.iterrows():
    G.add_node(row['Id'], Label=row['NODE_NAME'], latitude=row['latitude'], longitude=row['longitude'], avg_pop=row['average population'])

for idx, row in jeju_links.iterrows():
    G.add_edge(row['Source'], row['Target'], weight=row['시간'])

def connectRes(graph, df, nodes_df):
    nodes_latitude = nx.get_node_attributes(graph, 'latitude')
    nodes_longitude = nx.get_node_attributes(graph, 'longitude')
    nodes_avg_pop = nx.get_node_attributes(graph, 'avg_pop')
    for idx, row in df.iterrows():
        distances = {}
        for key, val in nodes_latitude.items():
            nodesPos = (val, nodes_longitude[key])
            curPos = (row['latitude'], row['longitude'])
            distances[key] = haversine(nodesPos, curPos, unit='km')
        nearest_node = min(distances, key=distances.get)
        avg_pop = nodes_avg_pop[nearest_node]
        graph.add_node(idx, Label=idx, latitude=row['latitude'], longitude=row['longitude'], avg_pop=avg_pop)
        w = distances[nearest_node] * 1000 / 666
        graph.add_edge(nearest_node, idx, weight=w)
    return graph

G = connectRes(G, car, nodes)

# %%
pos = {node[0]: [node[1]['longitude'], node[1]['latitude']] for node in G.nodes(data=True)}

def propagation(G, start_node, w=5):
    shortest_paths = nx.single_source_dijkstra_path_length(G, start_node, cutoff=w, weight='weight')
    return shortest_paths

def mergeDict(dict1, dict2):
    result_dict = {}
    for key in set(dict1.keys()).intersection(dict2.keys()):
        result_dict[key] = min(dict1[key], dict2[key])
    result_dict.update({key: dict1[key] for key in set(dict1.keys()) - set(dict2.keys())})
    result_dict.update({key: dict2[key] for key in set(dict2.keys()) - set(dict1.keys())})
    return result_dict

# %%
serviceArea = {}
for idx, row in car.iterrows():
    tmp = propagation(G, idx, w=5)
    serviceArea[idx] = list(tmp.keys())  # Ensure each service area maps to a list of nodes

# %%
#서비스 지역이 겹치는 노드들에 대해서 인구수를 분할해서 할당한다. 몇 번 겹치는 체크한다.
nodes['servicearea_counts'] = nodes['Id'].apply(lambda x: sum(1 for areas in serviceArea.values() if x in areas))


print(nodes)
# Out:
#               Id  NODE_NAME   latitude   longitude  average population  \
# 0     4060029000  서홍동1481-1  33.254678  126.512735           76.550725
# 1     4060187801       디아넥스  33.302487  126.393318           66.243386
# 2     4060014200        대기정  33.240456  126.427825          130.484211
# 3     4050113000   함덕리828-3  33.529426  126.667921          124.565217
# 4     4050113700   북촌리187-2  33.543350  126.702718          124.565217
# ...          ...        ...        ...         ...                 ...
# 4213  4060120700     상창육교동측  33.280072  126.362147           66.243386
# 4214  4060123100     하례2교차로  33.291300  126.609921           55.364458
# 4215  4060124900        신례교  33.293473  126.624560           55.364458
# 4216  4060126100     신례어린이집  33.288583  126.627921           55.364458
# 4217  4060126200      하례교차로  33.263485  126.629204           55.364458
#
#       servicearea_counts
# 0                      2
# 1                      0
# 2                      1
# ...

# %%
nodes['final_average_population'] = nodes.apply(lambda row: row['average population'] / row['servicearea_counts'] if row['servicearea_counts'] > 0 else row['average population'], axis=1)


# nodes['final_average_population'] = nodes.apply(lambda row: row['average population'] if row['servicearea_counts'] == 0 else row['final_average_population'], axis=1)

print(nodes)
# Out:
#               Id  NODE_NAME   latitude   longitude  average population  \
# 0     4060029000  서홍동1481-1  33.254678  126.512735           76.550725
# 1     4060187801       디아넥스  33.302487  126.393318           66.243386
# 2     4060014200        대기정  33.240456  126.427825          130.484211
# 3     4050113000   함덕리828-3  33.529426  126.667921          124.565217
# 4     4050113700   북촌리187-2  33.543350  126.702718          124.565217
# ...          ...        ...        ...         ...                 ...
# 4213  4060120700     상창육교동측  33.280072  126.362147           66.243386
# 4214  4060123100     하례2교차로  33.291300  126.609921           55.364458
# 4215  4060124900        신례교  33.293473  126.624560           55.364458
# 4216  4060126100     신례어린이집  33.288583  126.627921           55.364458
# 4217  4060126200      하례교차로  33.263485  126.629204           55.364458
#
#       servicearea_counts  final_average_population
# 0                      2                 38.275362
# ...

# %%
nodes.to_csv('data/Jeju_nodes.csv', encoding='utf-8', index=False)

# 결과 출력
print(nodes)
# Out:
#               Id  NODE_NAME   latitude   longitude  average population  \
# 0     4060029000  서홍동1481-1  33.254678  126.512735           76.550725
# 1     4060187801       디아넥스  33.302487  126.393318           66.243386
# 2     4060014200        대기정  33.240456  126.427825          130.484211
# 3     4050113000   함덕리828-3  33.529426  126.667921          124.565217
# 4     4050113700   북촌리187-2  33.543350  126.702718          124.565217
# ...          ...        ...        ...         ...                 ...
# 4213  4060120700     상창육교동측  33.280072  126.362147           66.243386
# 4214  4060123100     하례2교차로  33.291300  126.609921           55.364458
# 4215  4060124900        신례교  33.293473  126.624560           55.364458
# 4216  4060126100     신례어린이집  33.288583  126.627921           55.364458
# 4217  4060126200      하례교차로  33.263485  126.629204           55.364458
#
#       final_average_population
# 0                    38.275362
# 1                    66.243386
# ...

# %%
# serviCe Area에 포함되는 노드들의 average_poplaton을 합쳐서 색의 투명도를 디르게 칠하기
import matplotlib.pyplot as plt


nodes = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8')
links = pd.read_csv('data/Jeju_links.csv', encoding='cp949')
car = pd.read_csv('data/Jeju_car.csv', encoding='cp949')


nodes = nodes[['Id', 'NODE_NAME', 'latitude', 'longitude', 'average population','final_average_population']]
links = links[['Source', 'Target', '시간']]
source_in = links['Source'].apply(lambda x: x in list(nodes['Id']))
target_in = links['Target'].apply(lambda x: x in list(nodes['Id']))
jeju_links = links[source_in & target_in]

# %%
G = nx.Graph()

for idx, row in nodes.iterrows():
    G.add_node(row['Id'], Label=row['NODE_NAME'], latitude=row['latitude'], longitude=row['longitude'], avg_pop=row['average population'],finalavg_pop=row['final_average_population'])

for idx, row in jeju_links.iterrows():
    G.add_edge(row['Source'], row['Target'], weight=row['시간'])

def connectRes(graph, df, nodes_df):
    nodes_latitude = nx.get_node_attributes(graph, 'latitude')
    nodes_longitude = nx.get_node_attributes(graph, 'longitude')
    nodes_avg_pop = nx.get_node_attributes(graph, 'finalavg_pop')
    for idx, row in df.iterrows():
        distances = {}
        for key, val in nodes_latitude.items():
            nodesPos = (val, nodes_longitude[key])
            curPos = (row['latitude'], row['longitude'])
            distances[key] = haversine(nodesPos, curPos, unit='km')
        nearest_node = min(distances, key=distances.get)
        avg_pop = nodes_avg_pop[nearest_node]
        graph.add_node(idx, Label=idx, latitude=row['latitude'], longitude=row['longitude'], avg_pop=avg_pop)
        w = distances[nearest_node] * 1000 / 666
        graph.add_edge(nearest_node, idx, weight=w)
    return graph

G = connectRes(G, car, nodes)

# %%
pos = {node[0]: [node[1]['longitude'], node[1]['latitude']] for node in G.nodes(data=True)}

def propagation(G, start_node, w=5):
    shortest_paths = nx.single_source_dijkstra_path_length(G, start_node, cutoff=w, weight='weight')
    return shortest_paths

def mergeDict(dict1, dict2):
    result_dict = {}
    for key in set(dict1.keys()).intersection(dict2.keys()):
        result_dict[key] = min(dict1[key], dict2[key])
    result_dict.update({key: dict1[key] for key in set(dict1.keys()) - set(dict2.keys())})
    result_dict.update({key: dict2[key] for key in set(dict2.keys()) - set(dict1.keys())})
    return result_dict

# %%
serviceArea = {}
for idx, row in car.iterrows():
    tmp = propagation(G, idx, w=5)
    serviceArea[idx] = list(tmp.keys())  # Ensure each service area maps to a list of nodes

# %%
# def get_area_transparency_values(G, serviceArea):
#     avg_populations = nx.get_node_attributes(G, 'finalavg_pop')
#     total_population = sum(avg_populations.values())
#     area_transparency_values = {}
#     for area_id, nodes_in_area in serviceArea.items():
#         area_population_sum = sum(avg_populations.get(node, 0) for node in nodes_in_area)
#         normalized_value = area_population_sum / total_population
#         area_transparency_values[area_id] = normalized_value
#     return area_transparency_values

# area_transparency_values = get_area_transparency_values(G, serviceArea)
def get_area_transparency_values(G, serviceArea):
    avg_populations = nx.get_node_attributes(G, 'finalavg_pop')
    total_population = sum(avg_populations.values())
    area_transparency_values = {}
    for area_id, nodes_in_area in serviceArea.items():
        area_population = sum(avg_populations.get(node, 0) for node in nodes_in_area)
        normalized_value = area_population / total_population
        area_transparency_values[area_id] = normalized_value
    return area_transparency_values

# %%
def draw(G, serviceArea, area_transparency_values, select_color='darkred'):
    plt.figure(figsize=(12, 7))
    plt.axis('off')
    nx.draw_networkx(G, pos=pos, node_size=0, with_labels=False, node_color='snow', edge_color='snow')
    for area_id, nodes_in_area in serviceArea.items():
        alpha = area_transparency_values.get(area_id, 1)
        nx.draw_networkx_nodes(G, pos, nodelist=nodes_in_area, node_color=select_color, alpha=alpha, node_size=1)
        edge_colors = [select_color if (u in nodes_in_area and v in nodes_in_area) else 'snow' for u, v in G.edges()]
        nx.draw_networkx_edges(G, pos, edge_color=edge_colors, alpha=alpha)
    plt.show()

# draw 함수 사용
draw(G, serviceArea, area_transparency_values)

# %%
import pandas as pd
import numpy as np
import networkx as nx

import matplotlib.pyplot as plt
# 읍 면 동이 행정동으로 구별된 것을 지도에 그리기
nodes = pd.read_csv('data/Jeju_nodes.csv', encoding='utf-8',sep=',')
links = pd.read_csv('data/Jeju_links.csv', encoding='cp949')
links
nodes = nodes[['Id','NODE_NAME','latitude','longitude','average population']]
links = links[['Source','Target']]
source_in = links['Source'].apply(lambda x : x in list(nodes['Id'])) # check Sources are in jeju_id
target_in = links['Target'].apply(lambda x : x in list(nodes['Id'])) # check Targets are in jeju_id
# source_in and target_in are boolean type pandas.Series which contains True or False
Jeju_links = links[source_in & target_in] # contain if both target and source are contained in jeju_id
G = nx.Graph()
# R is the Earth's radius
R = 6371e3

# %%
for idx,row in nodes.iterrows():
    # add node to Graph G
    G.add_node(row['Id'],Label=row['NODE_NAME'],latitude=row['latitude'], longitude=row['longitude'])

for idx,row in Jeju_links.iterrows():
    ## Calculate the distance between Source and Target Nodes
    lon1 = float(nodes[nodes['Id'] == row['Source']]['longitude'] * np.pi/180)
    lat1 = float(nodes[nodes['Id'] == row['Source']]['latitude'] * np.pi/180)
    lon2 = float(nodes[nodes['Id'] == row['Target']]['longitude'] * np.pi/180)
    lat2 = float(nodes[nodes['Id'] == row['Target']]['latitude'] * np.pi/180)
    d_lat = lat2 - lat1
    d_lon = lon2 - lon1
    a = np.sin(d_lat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(d_lon/2) ** 2
    c = 2 * np.arctan2(a**0.5, (1-a) ** 0.5)
    d = R * c
    
    # Link attribute : 'Source', 'Target' and weight = 'Length between them'
    G.add_edge(row['Source'],row['Target'],weight = d)

# %%
# make a dictionary for node position
pos = {}
for node in G.nodes(data=True):
    pos[node[0]] = [node[1]['longitude'], node[1]['latitude']]
print(pos)
from matplotlib.colors import ListedColormap
# Out:
# {4060029000: [126.512734734648, 33.2546781470705], 4060187801: [126.393318242941, 33.3024873661656], 4060014200: [126.427824763833, 33.2404562739723], 4050113000: [126.667921008318, 33.5294259271958], 4050113700: [126.702717929053, 33.5433495414616], 4050113900: [126.693206207319, 33.5500237666183], 4060000800: [126.478039080718, 33.2511516704185], 4060003403: [126.595401810657, 33.259624267661], 4060004001: [126.612293095372, 33.2611697419915], 4060004201: [126.428245623643, 33.258049186505], 4060073300: [126.467102315343, 33.263421015703], 4060073400: [126.474326735403, 33.2561718396282], 4060073900: [126.514023434851, 33.2366074758841], 4060074300: [126.475651731667, 33.2362573635155], 4060076200: [126.561106833762, 33.2468565391276], 4050000503: [126.489959245415, 33.41828117736], 4050000600: [126.616698292577, 33.4191031477377], 4050129700: [126.258499828867, 33.3048245714679], 4050130300: [126.259139099184, 33.4094155336075], 4050164300: [126.405096018178, 33.4836605799511], 40
# ...

# %%
# 노드별 인구수 기준으로 색상 맵 생성
unique_populations = nodes['average population'].unique()
max_population = nodes['average population'].max()
color_map = plt.cm.Blues  

# 인구수에 따른 색상 할당
population_color = {population: color_map(population / max_population) for population in unique_populations}


def get_node_attributes(node):
    avg_population = nodes[nodes['Id'] == node]['average population'].values[0]
    color = population_color[avg_population]
    size = 10 
    if avg_population == 0:
        color = 'white'  
    return color, size


node_colors = [get_node_attributes(node)[0] for node in G.nodes()]
node_sizes = [get_node_attributes(node)[1] for node in G.nodes()]


def draw_graph(G, pos, node_colors, node_sizes):
    plt.figure(figsize=(12, 7))
    plt.axis('off')
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=node_sizes)
    nx.draw_networkx_edges(G, pos, edge_color='grey')

    # 칼러바를 위한 정규화 객체 생성
    norm = plt.Normalize(vmin=0, vmax=max_population)

    # 칼러바를 그리기 위한 스칼라 매핑 객체 생성
    sm = plt.cm.ScalarMappable(cmap=color_map, norm=norm)
    sm.set_array([])

    # 칼러바 추가
    plt.colorbar(sm, orientation='vertical', label='Average Population')

    plt.show()

# 그래프 그리기
draw_graph(G, pos, node_colors, node_sizes)

# %%
import numpy as np
import matplotlib.colors as mcolors

# 로그 스케일을 적용한 인구수에 따른 색상 넣기
population_color = {
    population: color_map(np.log1p(population) / np.log1p(max_population))
    for population in unique_populations
}


def get_node_attributes(node):
    avg_population = nodes[nodes['Id'] == node]['average population'].values[0]
    color = population_color[avg_population]
    size = 3
    if avg_population == 0:
        color = 'white'
    return color, size

node_colors = [get_node_attributes(node)[0] for node in G.nodes()]
node_sizes = [get_node_attributes(node)[1] for node in G.nodes()]

def draw_graph(G, pos, node_colors, node_sizes, edge_colors):
    plt.figure(figsize=(12, 7))
    plt.axis('off')
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=node_sizes)
    nx.draw_networkx_edges(G, pos, edge_color=edge_colors)
    plt.show()

node_colors_dict = {node: get_node_attributes(node)[0] for node in G.nodes()}
edge_colors = [get_edge_color(u, v, node_colors_dict) for u, v in G.edges()]

draw_graph(G, pos, node_colors, node_sizes, edge_colors)

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# 색상 맵 설정 (예: 'Blues')
color_map = plt.get_cmap('Blues')

# unique_populations, max_population 정의
# 예시 데이터를 사용하거나 실제 데이터셋에서 계산
unique_populations = nodes['average population'].unique()
max_population = nodes['average population'].max()

# 로그 스케일을 적용한 인구수에 따른 색상 매핑
population_color = {
    population: color_map(np.log1p(population) / np.log1p(max_population))
    for population in unique_populations
}

# 노드 속성을 반환하는 함수
def get_node_attributes(node):
    avg_population = nodes[nodes['Id'] == node]['average population'].values[0]
    color = population_color[avg_population]
    size = 10
    if avg_population == 0:
        color = 'white'
    return color, size

# 노드 색상과 크기 설정
node_colors = [get_node_attributes(node)[0] for node in G.nodes()]
node_sizes = [get_node_attributes(node)[1] for node in G.nodes()]

# 네트워크 그래프를 그리는 함수
def draw_graph(G, pos, node_colors, node_sizes):
    plt.figure(figsize=(12, 7))
    plt.axis('off')
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=node_sizes)
    nx.draw_networkx_edges(G, pos, edge_color='grey')

    # 칼러바를 위한 정규화 객체 생성
    min_population = min(unique_populations[unique_populations > 0])
    norm = plt.Normalize(vmin=(np.log1p(min_population)/np.log1p(max_population)), vmax=1)

    # 칼러바를 그리기 위한 스칼라 매핑 객체 생성
    sm = plt.cm.ScalarMappable(cmap=color_map, norm=norm)
    sm.set_array([])

    # 칼러바 추가
    plt.colorbar(sm, orientation='vertical', label='Log scale Average Population')

    plt.show()

# 그래프 그리기
draw_graph(G, pos, node_colors, node_sizes)
